# %%
# %load_ext autoreload
# %autoreload 2

import sys
import os

# Get the absolute path of the parent directory
parent_dir = os.path.abspath('..')

# Add the parent directory to the system path
if parent_dir not in sys.path:
    sys.path.insert(0, parent_dir)

from jssp_env import visualizer
from jssp_env import models
from jssp_env import parser
from jssp_env import or_solvers

# %%
jssp_instance = parser.parse_jssp_instance_from_file("../data/ft10.txt")

# %%
or_solvers.solve_jssp_exact(jssp_instance)
visualizer.visualize_gantt_chart(jssp_instance)
# Out:
# machines_count = 10
# Horizon: 5109
# -------------------- RAW RESULTS --------------------
# Status: CpSolverStatus.OPTIMAL
# 	4 - OPTIMAL: Optimal solution, mathematically no better solution exists
# 	3 - INFEASIBLE: No solution exists
# 	2 - FEASIBLE: Found a valid solution but couldn't prove it's the best (lack of time or resources)
# 	1 - MODEL_INVALID: Broken logic in the model
# 	0 - UNKNOWN: Didn't find anything but can't prove no solution exists (lack of time or resources)
# Schedule Length (optimal or not): 930.0
# job 0, task 0 -> start: 43 & end: 72
# job 0, task 1 -> start: 447 & end: 525
# job 0, task 2 -> start: 525 & end: 534
# job 0, task 3 -> start: 535 & end: 571
# job 0, task 4 -> start: 571 & end: 620
# job 0, task 5 -> start: 644 & end: 655
# job 0, task 6 -> start: 655 & end: 717
# job 0, task 7 -> start: 721 & end: 777
# job 0, task 8 -> start: 792 & end: 836
# job 0, task 9 -> start: 897 & end: 918
# job 1, task 0 -> start: 0 & end: 43
# ...
